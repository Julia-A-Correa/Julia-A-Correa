# %%
def boas_vindas():
  print("Bem vindo")

# %%
boas_vindas()
# Out:
# Bem vindo

# %%
def bemvindo(nomeUsuario):
  print("Boa tarde", nomeUsuario, "Seja bem vindo")

nomeUsuario = input()
bemvindo(nomeUsuario)
# Out:
# Renan
# Boa tarde Renan Seja bem vindo

# %%
def filme_favorito(titulo):
    print(f"Um dos meus filmes favoritos é {titulo}.")
filme_favorito("A Origem")
filme_favorito("Senhor dos Anéis: A Sociedade do Anel")
filme_favorito("Matrix")
filme_favorito("Interestelar")
filme_favorito("O Rei Leão")
# Out:
# Um dos meus filmes favoritos é A Origem.
# Um dos meus filmes favoritos é Senhor dos Anéis: A Sociedade do Anel.
# Um dos meus filmes favoritos é Matrix.
# Um dos meus filmes favoritos é Interestelar.
# Um dos meus filmes favoritos é O Rei Leão.

# %%
def menor(a, b):
  if a<=b:
    return a
  else:
    return b

# %%
a = 10
b = 15

print("O menor valor entre " ,a, "e" ,b, "é" ,menor(a, b))
# Out:
# O menor valor entre  10 e 15 é 10

# %%
def Saudacao():
  print("Olá! Seja bem-vindo(a) ao curso em Python!")
Saudacao()
# Out:
# Olá! Seja bem-vindo(a) ao curso em Python!

# %%
def boas_vindas(nome):
  print(f"Olá, {nome}! Que bom ver você por aqui!")
boas_vindas("Arthur")
# Out:
# Olá, Arthur! Que bom ver você por aqui!
